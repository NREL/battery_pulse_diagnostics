# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append("../../")
import torch
import xgboost as xgb
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error, max_error, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
def plot_true_vs_pred_axis(ax, pulse, target, result_dict, color='blue', n_splits=50, title=''):
    df = result_dict[f"{target}, {pulse}"]
    average_pred = df[list(range(n_splits))].mean(axis=1)
    sns.histplot(x=df[target],
        y=average_pred,
        stat='percent',
        bins=30,
        color=color,
        ax=ax)
    ax.axline( (df[target].min(), df[target].min()),
                       (df[target].max(), df[target].max()),
                     linestyle='dashed', color='gray')
    ax.set_title(title)
    # ax.annotate("r^2: {:.3f}".format(r2_score(df[target], average_pred)), xy=(0.05, 0.9), xycoords='axes fraction', fontsize=8)

# %%
fig, ax = plt.subplots(2,4, figsize=(12, 5))

A = torch.load('../../results/bootstrap_results_A.pth', weights_only=False)
B = torch.load('../../results/bootstrap_results_B.pth', weights_only=False)
C = torch.load('../../results/bootstrap_results_C.pth', weights_only=False)
D = torch.load('../../results/bootstrap_results_D.pth', weights_only=False)

pulses = [
    "Charge_Depleting",
]

targets = [
    "C/3 discharge capacity",
    "soc_mean",
]

data = [A,B,C,D]

for i in range(4):
    for j in range(2):
        plot_true_vs_pred_axis(ax[j,i], pulses[0], targets[j], data[i], n_splits=50, title=f"Dataset {chr(65+i)}")

fig.tight_layout()

# %%
hdf = pd.HDFStore('../../data/data_partial_charge_for_ml.h5', mode='r')
keys = hdf.keys()
keys
# Out:
# ['/Charge_Depleting',
#  '/Charge_Sustaining',
#  '/PsRP_1_1C',
#  '/PsRP_2_1C',
#  '/Rate_Test_1C',
#  '/Rate_Test_C/2',
#  '/PsRP_2_C/2',
#  '/PsRP_1_C/2']

# %%
df = hdf.get('/Rate_Test_C/2')

# df
list(df.columns)
# Out:
# ['soc_mean',
#  'soc_initial',
#  'soc_final',
#  'voltage_0.0s',
#  'voltage_1.0s',
#  'voltage_2.0s',
#  'voltage_3.0s',
#  'voltage_4.0s',
#  'voltage_5.0s',
#  'voltage_6.0s',
#  'voltage_7.0s',
#  'voltage_8.0s',
#  'voltage_9.0s',
#  'voltage_10.0s',
#  'voltage_11.0s',
#  'voltage_12.0s',
#  'voltage_13.0s',
#  'voltage_14.0s',
#  'voltage_15.0s',
#  'voltage_16.0s',
#  'voltage_17.0s',
#  'voltage_18.0s',
#  'voltage_19.0s',
#  'voltage_20.0s',
#  'voltage_21.0s',
#  'voltage_22.0s',
#  'voltage_23.0s',
#  'voltage_24.0s',
#  'voltage_25.0s',
#  'voltage_26.0s',
#  'voltage_27.0s',
#  'voltage_28.0s',
#  'voltage_29.0s',
#  'voltage_30.0s',
#  'voltage_31.0s',
#  'voltage_32.0s',
#  'voltage_33.0s',
#  'voltage_34.0s',
#  'voltage_35.0s',
#  'voltage_36.0s',
#  'voltage_37.0s',
#  'voltage_38.0s',
#  'voltage_39.0s',
#  'voltage_40.0s',
#  'voltage_41.0s',
#  'voltage_42.0s',
#  'voltage_43.0s',
#  'voltage_44.0s',
#  'voltage_45.0s',
#  'voltage_46.0s',
#  'voltage_47.0s',
#  'voltage_48.0s',
#  'voltage_49.0s',
#  'voltage_50.0s',
#  'voltage_51.0s',
#  'voltage_52.0s',
#  'voltage_53.0s',
#  'voltage_54.0s',
#  'voltage_55.0s',
#  'voltage_56.0s',
#  'voltage_57.0s',
#  'voltage_58.0s',
#  'voltage_59.0s',
#  'voltage_60.0s',
#  'voltage_61.0s',
#  'voltage_62.0s',
#  'voltage_63.0s',
#  'voltage_64.0s',
#  'voltage_65.0s',
#  'voltage_66.0s',
#  'voltage_67.0s',
#  'voltage_68.0s',
#  'voltage_69.0s',
#  'voltage_70.0s',
#  'voltage_71.0s',
#  'voltage_72.0s',
#  'voltage_73.0s',
#  'voltage_74.0s',
#  'voltage_75.0s',
#  'voltage_76.0s',
#  'voltage_77.0s',
#  'voltage_78.0s',
#  'voltage_79.0s',
#  'voltage_80.0s',
#  'voltage_81.0s',
#  'voltage_82.0s',
#  'voltage_83.0s',
#  'voltage_84.0s',
#  'voltage_85.0s',
#  'voltage_86.0s',
#  'voltage_87.0s',
#  'voltage_88.0s',
#  'voltage_89.0s',
#  'voltage_90.0s',
#  'voltage_91.0s',
#  'voltage_92.0s',
#  'voltage_93.0s',
#  'voltage_94.0s',
#  'voltage_95.0s',
#  'voltage_96.0s',
#  'voltage_97.0s',
#  'voltage_98.0s',
#  'voltage_99.0s',
#  'voltage_100.0s',
#  'voltage_101.0s',
#  'voltage_102.0s',
#  'voltage_103.0s',
#  'voltage_104.0s',
#  'voltage_105.0s',
#  'voltage_106.0s',
#  'voltage_107.0s',
#  'voltage_108.0s',
#  'voltage_109.0s',
#  'voltage_110.0s',
#  'voltage_111.0s',
#  'voltage_112.0s',
#  'voltage_113.0s',
#  'voltage_114.0s',
#  'voltage_115.0s',
#  'voltage_116.0s',
#  'voltage_117.0s',
#  'voltage_118.0s',
#  'voltage_119.0s',
#  'voltage_120.0s',
#  'voltage_121.0s',
#  'voltage_122.0s',
#  'voltage_123.0s',
#  'voltage_124.0s',
#  'voltage_125.0s',
#  'voltage_126.0s',
#  'voltage_127.0s',
#  'voltage_128.0s',
#  'voltage_129.0s',
#  'voltage_130.0s',
#  'voltage_131.0s',
#  'voltage_132.0s',
#  'voltage_133.0s',
#  'voltage_134.0s',
#  'voltage_135.0s',
#  'voltage_136.0s',
#  'voltage_137.0s',
#  'voltage_138.0s',
#  'voltage_139.0s',
#  'voltage_140.0s',
#  'voltage_141.0s',
#  'voltage_142.0s',
#  'voltage_143.0s',
#  'voltage_144.0s',
#  'voltage_145.0s',
#  'voltage_146.0s',
#  'voltage_147.0s',
#  'voltage_148.0s',
#  'voltage_149.0s',
#  'voltage_150.0s',
#  'voltage_151.0s',
#  'voltage_152.0s',
#  'voltage_153.0s',
#  'voltage_154.0s',
#  'voltage_155.0s',
#  'voltage_156.0s',
#  'voltage_157.0s',
#  'voltage_158.0s',
#  'voltage_159.0s',
#  'voltage_160.0s',
#  'voltage_161.0s',
#  'voltage_162.0s',
#  'voltage_163.0s',
#  'voltage_164.0s',
#  'voltage_165.0s',
#  'voltage_166.0s',
#  'voltage_167.0s',
#  'voltage_168.0s',
#  'voltage_169.0s',
#  'voltage_170.0s',
#  'voltage_171.0s',
#  'voltage_172.0s',
#  'voltage_173.0s',
#  'voltage_174.0s',
#  'voltage_175.0s',
#  'voltage_176.0s',
#  'voltage_177.0s',
#  'voltage_178.0s',
#  'voltage_179.0s',
#  'voltage_180.0s',
#  'voltage_181.0s',
#  'voltage_182.0s',
#  'voltage_183.0s',
#  'voltage_184.0s',
#  'voltage_185.0s',
#  'voltage_186.0s',
#  'voltage_187.0s',
#  'voltage_188.0s',
#  'voltage_189.0s',
#  'voltage_190.0s',
#  'voltage_191.0s',
#  'voltage_192.0s',
#  'voltage_193.0s',
#  'voltage_194.0s',
#  'voltage_195.0s',
#  'voltage_196.0s',
#  'voltage_197.0s',
#  'voltage_198.0s',
#  'voltage_199.0s',
#  'voltage_200.0s',
#  'voltage_201.0s',
#  'voltage_202.0s',
#  'voltage_203.0s',
#  'voltage_204.0s',
#  'voltage_205.0s',
#  'voltage_206.0s',
#  'voltage_207.0s',
#  'voltage_208.0s',
#  'voltage_209.0s',
#  'voltage_210.0s',
#  'voltage_211.0s',
#  'voltage_212.0s',
#  'voltage_213.0s',
#  'voltage_214.0s',
#  'voltage_215.0s',
#  'voltage_216.0s',
#  'voltage_217.0s',
#  'voltage_218.0s',
#  'voltage_219.0s',
#  'voltage_220.0s',
#  'voltage_221.0s',
#  'voltage_222.0s',
#  'voltage_223.0s',
#  'voltage_224.0s',
#  'voltage_225.0s',
#  'voltage_226.0s',
#  'voltage_227.0s',
#  'voltage_228.0s',
#  'voltage_229.0s',
#  'voltage_230.0s',
#  'voltage_231.0s',
#  'voltage_232.0s',
#  'voltage_233.0s',
#  'voltage_234.0s',
#  'voltage_235.0s',
#  'voltage_236.0s',
#  'voltage_237.0s',
#  'voltage_238.0s',
#  'voltage_239.0s',
#  'voltage_240.0s',
#  'voltage_241.0s',
#  'voltage_242.0s',
#  'voltage_243.0s',
#  'voltage_244.0s',
#  'voltage_245.0s',
#  'voltage_246.0s',
#  'voltage_247.0s',
#  'voltage_248.0s',
#  'voltage_249.0s',
#  'voltage_250.0s',
#  'voltage_251.0s',
#  'voltage_252.0s',
#  'voltage_253.0s',
#  'voltage_254.0s',
#  'voltage_255.0s',
#  'voltage_256.0s',
#  'voltage_257.0s',
#  'voltage_258.0s',
#  'voltage_259.0s',
#  'voltage_260.0s',
#  'voltage_261.0s',
#  'voltage_262.0s',
#  'voltage_263.0s',
#  'voltage_264.0s',
#  'voltage_265.0s',
#  'voltage_266.0s',
#  'voltage_267.0s',
#  'voltage_268.0s',
#  'voltage_269.0s',
#  'voltage_270.0s',
#  'voltage_271.0s',
#  'voltage_272.0s',
#  'voltage_273.0s',
#  'voltage_274.0s',
#  'voltage_275.0s',
#  'voltage_276.0s',
#  'voltage_277.0s',
#  'voltage_278.0s',
#  'voltage_279.0s',
#  'voltage_280.0s',
#  'voltage_281.0s',
#  'voltage_282.0s',
#  'voltage_283.0s',
#  'voltage_284.0s',
#  'voltage_285.0s',
#  'voltage_286.0s',
#  'voltage_287.0s',
#  'voltage_288.0s',
#  'voltage_289.0s',
#  'voltage_290.0s',
#  'voltage_291.0s',
#  'voltage_292.0s',
#  'voltage_293.0s',
#  'voltage_294.0s',
#  'voltage_295.0s',
#  'voltage_296.0s',
#  'voltage_297.0s',
#  'voltage_298.0s',
#  'voltage_299.0s',
#  'voltage_300.0s',
#  'voltage_301.0s',
#  'voltage_302.0s',
#  'voltage_303.0s',
#  'voltage_304.0s',
#  'voltage_305.0s',
#  'voltage_306.0s',
#  'voltage_307.0s',
#  'voltage_308.0s',
#  'voltage_309.0s',
#  'voltage_310.0s',
#  'voltage_311.0s',
#  'voltage_312.0s',
#  'voltage_313.0s',
#  'voltage_314.0s',
#  'voltage_315.0s',
#  'voltage_316.0s',
#  'voltage_317.0s',
#  'voltage_318.0s',
#  'voltage_319.0s',
#  'voltage_320.0s',
#  'voltage_321.0s',
#  'voltage_322.0s',
#  'voltage_323.0s',
#  'voltage_324.0s',
#  'voltage_325.0s',
#  'voltage_326.0s',
#  'voltage_327.0s',
#  'voltage_328.0s',
#  'voltage_329.0s',
#  'voltage_330.0s',
#  'voltage_331.0s',
#  'voltage_332.0s',
#  'voltage_333.0s',
#  'voltage_334.0s',
#  'voltage_335.0s',
#  'voltage_336.0s',
#  'voltage_337.0s',
#  'voltage_338.0s',
#  'voltage_339.0s',
#  'voltage_340.0s',
#  'voltage_341.0s',
#  'voltage_342.0s',
#  'voltage_343.0s',
#  'voltage_344.0s',
#  'voltage_345.0s',
#  'voltage_346.0s',
#  'voltage_347.0s',
#  'voltage_348.0s',
#  'voltage_349.0s',
#  'voltage_350.0s',
#  'voltage_351.0s',
#  'voltage_352.0s',
#  'voltage_353.0s',
#  'voltage_354.0s',
#  'voltage_355.0s',
#  'voltage_356.0s',
#  'voltage_357.0s',
#  'voltage_358.0s',
#  'voltage_359.0s',
#  'voltage_360.0s',
#  'voltage_361.0s',
#  'voltage_362.0s',
#  'voltage_363.0s',
#  'voltage_364.0s',
#  'voltage_365.0s',
#  'voltage_366.0s',
#  'voltage_367.0s',
#  'voltage_368.0s',
#  'voltage_369.0s',
#  'voltage_370.0s',
#  'voltage_371.0s',
#  'voltage_372.0s',
#  'voltage_373.0s',
#  'voltage_374.0s',
#  'voltage_375.0s',
#  'voltage_376.0s',
#  'voltage_377.0s',
#  'voltage_378.0s',
#  'voltage_379.0s',
#  'voltage_380.0s',
#  'voltage_381.0s',
#  'voltage_382.0s',
#  'voltage_383.0s',
#  'voltage_384.0s',
#  'voltage_385.0s',
#  'voltage_386.0s',
#  'voltage_387.0s',
#  'voltage_388.0s',
#  'voltage_389.0s',
#  'voltage_390.0s',
#  'voltage_391.0s',
#  'voltage_392.0s',
#  'voltage_393.0s',
#  'voltage_394.0s',
#  'voltage_395.0s',
#  'voltage_396.0s',
#  'voltage_397.0s',
#  'voltage_398.0s',
#  'voltage_399.0s',
#  'voltage_400.0s',
#  'voltage_401.0s',
#  'voltage_402.0s',
#  'voltage_403.0s',
#  'voltage_404.0s',
#  'voltage_405.0s',
#  'voltage_406.0s',
#  'voltage_407.0s',
#  'voltage_408.0s',
#  'voltage_409.0s',
#  'voltage_410.0s',
#  'voltage_411.0s',
#  'voltage_412.0s',
#  'voltage_413.0s',
#  'voltage_414.0s',
#  'voltage_415.0s',
#  'voltage_416.0s',
#  'voltage_417.0s',
#  'voltage_418.0s',
#  'voltage_419.0s',
#  'voltage_420.0s',
#  'voltage_421.0s',
#  'voltage_422.0s',
#  'voltage_423.0s',
#  'voltage_424.0s',
#  'voltage_425.0s',
#  'voltage_426.0s',
#  'voltage_427.0s',
#  'voltage_428.0s',
#  'voltage_429.0s',
#  'voltage_430.0s',
#  'voltage_431.0s',
#  'voltage_432.0s',
#  'voltage_433.0s',
#  'voltage_434.0s',
#  'voltage_435.0s',
#  'voltage_436.0s',
#  'voltage_437.0s',
#  'voltage_438.0s',
#  'voltage_439.0s',
#  'voltage_440.0s',
#  'voltage_441.0s',
#  'voltage_442.0s',
#  'voltage_443.0s',
#  'voltage_444.0s',
#  'voltage_445.0s',
#  'voltage_446.0s',
#  'voltage_447.0s',
#  'voltage_448.0s',
#  'voltage_449.0s',
#  'voltage_450.0s',
#  'voltage_451.0s',
#  'voltage_452.0s',
#  'voltage_453.0s',
#  'voltage_454.0s',
#  'voltage_455.0s',
#  'voltage_456.0s',
#  'voltage_457.0s',
#  'voltage_458.0s',
#  'voltage_459.0s',
#  'voltage_460.0s',
#  'voltage_461.0s',
#  'voltage_462.0s',
#  'voltage_463.0s',
#  'voltage_464.0s',
#  'voltage_465.0s',
#  'voltage_466.0s',
#  'voltage_467.0s',
#  'voltage_468.0s',
#  'voltage_469.0s',
#  'voltage_470.0s',
#  'voltage_471.0s',
#  'voltage_472.0s',
#  'voltage_473.0s',
#  'voltage_474.0s',
#  'voltage_475.0s',
#  'voltage_476.0s',
#  'voltage_477.0s',
#  'voltage_478.0s',
#  'voltage_479.0s',
#  'voltage_480.0s',
#  'voltage_481.0s',
#  'voltage_482.0s',
#  'voltage_483.0s',
#  'voltage_484.0s',
#  'voltage_485.0s',
#  'voltage_486.0s',
#  'voltage_487.0s',
#  'voltage_488.0s',
#  'voltage_489.0s',
#  'voltage_490.0s',
#  'voltage_491.0s',
#  'voltage_492.0s',
#  'voltage_493.0s',
#  'voltage_494.0s',
#  'voltage_495.0s',
#  'voltage_496.0s',
#  'voltage_497.0s',
#  'voltage_498.0s',
#  'voltage_499.0s',
#  'voltage_500.0s',
#  'voltage_501.0s',
#  'voltage_502.0s',
#  'voltage_503.0s',
#  'voltage_504.0s',
#  'voltage_505.0s',
#  'voltage_506.0s',
#  'voltage_507.0s',
#  'voltage_508.0s',
#  'voltage_509.0s',
#  'voltage_510.0s',
#  'voltage_511.0s',
#  'voltage_512.0s',
#  'voltage_513.0s',
#  'voltage_514.0s',
#  'voltage_515.0s',
#  'voltage_516.0s',
#  'voltage_517.0s',
#  'voltage_518.0s',
#  'voltage_519.0s',
#  'voltage_520.0s',
#  'voltage_521.0s',
#  'voltage_522.0s',
#  'voltage_523.0s',
#  'voltage_524.0s',
#  'voltage_525.0s',
#  'voltage_526.0s',
#  'voltage_527.0s',
#  'voltage_528.0s',
#  'voltage_529.0s',
#  'voltage_530.0s',
#  'voltage_531.0s',
#  'voltage_532.0s',
#  'voltage_533.0s',
#  'voltage_534.0s',
#  'voltage_535.0s',
#  'voltage_536.0s',
#  'voltage_537.0s',
#  'voltage_538.0s',
#  'voltage_539.0s',
#  'voltage_540.0s',
#  'voltage_541.0s',
#  'voltage_542.0s',
#  'voltage_543.0s',
#  'voltage_544.0s',
#  'voltage_545.0s',
#  'voltage_546.0s',
#  'voltage_547.0s',
#  'voltage_548.0s',
#  'voltage_549.0s',
#  'voltage_550.0s',
#  'voltage_551.0s',
#  'voltage_552.0s',
#  'voltage_553.0s',
#  'voltage_554.0s',
#  'voltage_555.0s',
#  'voltage_556.0s',
#  'voltage_557.0s',
#  'voltage_558.0s',
#  'voltage_559.0s',
#  'voltage_560.0s',
#  'voltage_561.0s',
#  'voltage_562.0s',
#  'voltage_563.0s',
#  'voltage_564.0s',
#  'voltage_565.0s',
#  'voltage_566.0s',
#  'voltage_567.0s',
#  'voltage_568.0s',
#  'voltage_569.0s',
#  'voltage_570.0s',
#  'voltage_571.0s',
#  'voltage_572.0s',
#  'voltage_573.0s',
#  'voltage_574.0s',
#  'voltage_575.0s',
#  'voltage_576.0s',
#  'voltage_577.0s',
#  'voltage_578.0s',
#  'voltage_579.0s',
#  'voltage_580.0s',
#  'voltage_581.0s',
#  'voltage_582.0s',
#  'voltage_583.0s',
#  'voltage_584.0s',
#  'voltage_585.0s',
#  'voltage_586.0s',
#  'voltage_587.0s',
#  'voltage_588.0s',
#  'voltage_589.0s',
#  'voltage_590.0s',
#  'voltage_591.0s',
#  'voltage_592.0s',
#  'voltage_593.0s',
#  'voltage_594.0s',
#  'voltage_595.0s',
#  'voltage_596.0s',
#  'voltage_597.0s',
#  'voltage_598.0s',
#  'voltage_599.0s',
#  'voltage_600.0s',
#  'voltage_601.0s',
#  'voltage_602.0s',
#  'voltage_603.0s',
#  'voltage_604.0s',
#  'voltage_605.0s',
#  'voltage_606.0s',
#  'voltage_607.0s',
#  'voltage_608.0s',
#  'voltage_609.0s',
#  'voltage_610.0s',
#  'voltage_611.0s',
#  'voltage_612.0s',
#  'voltage_613.0s',
#  'voltage_614.0s',
#  'voltage_615.0s',
#  'voltage_616.0s',
#  'voltage_617.0s',
#  'voltage_618.0s',
#  'voltage_619.0s',
#  'voltage_620.0s',
#  'voltage_621.0s',
#  'voltage_622.0s',
#  'voltage_623.0s',
#  'voltage_624.0s',
#  'voltage_625.0s',
#  'voltage_626.0s',
#  'voltage_627.0s',
#  'voltage_628.0s',
#  'voltage_629.0s',
#  'voltage_630.0s',
#  'voltage_631.0s',
#  'voltage_632.0s',
#  'voltage_633.0s',
#  'voltage_634.0s',
#  'voltage_635.0s',
#  'voltage_636.0s',
#  'voltage_637.0s',
#  'voltage_638.0s',
#  'voltage_639.0s',
#  'voltage_640.0s',
#  'voltage_641.0s',
#  'voltage_642.0s',
#  'voltage_643.0s',
#  'voltage_644.0s',
#  'voltage_645.0s',
#  'voltage_646.0s',
#  'voltage_647.0s',
#  'voltage_648.0s',
#  'voltage_649.0s',
#  'voltage_650.0s',
#  'voltage_651.0s',
#  'voltage_652.0s',
#  'voltage_653.0s',
#  'voltage_654.0s',
#  'voltage_655.0s',
#  'voltage_656.0s',
#  'voltage_657.0s',
#  'voltage_658.0s',
#  'voltage_659.0s',
#  'voltage_660.0s',
#  'voltage_661.0s',
#  'voltage_662.0s',
#  'voltage_663.0s',
#  'voltage_664.0s',
#  'voltage_665.0s',
#  'voltage_666.0s',
#  'voltage_667.0s',
#  'voltage_668.0s',
#  'voltage_669.0s',
#  'voltage_670.0s',
#  'voltage_671.0s',
#  'voltage_672.0s',
#  'voltage_673.0s',
#  'voltage_674.0s',
#  'voltage_675.0s',
#  'voltage_676.0s',
#  'voltage_677.0s',
#  'voltage_678.0s',
#  'voltage_679.0s',
#  'voltage_680.0s',
#  'voltage_681.0s',
#  'voltage_682.0s',
#  'voltage_683.0s',
#  'voltage_684.0s',
#  'voltage_685.0s',
#  'voltage_686.0s',
#  'voltage_687.0s',
#  'voltage_688.0s',
#  'voltage_689.0s',
#  'voltage_690.0s',
#  'voltage_691.0s',
#  'voltage_692.0s',
#  'voltage_693.0s',
#  'voltage_694.0s',
#  'voltage_695.0s',
#  'voltage_696.0s',
#  'voltage_697.0s',
#  'voltage_698.0s',
#  'voltage_699.0s',
#  'voltage_700.0s',
#  'voltage_701.0s',
#  'voltage_702.0s',
#  'voltage_703.0s',
#  'voltage_704.0s',
#  'voltage_705.0s',
#  'voltage_706.0s',
#  'voltage_707.0s',
#  'voltage_708.0s',
#  'voltage_709.0s',
#  'voltage_710.0s',
#  'voltage_711.0s',
#  'voltage_712.0s',
#  'voltage_713.0s',
#  'voltage_714.0s',
#  'voltage_715.0s',
#  'voltage_716.0s',
#  'voltage_717.0s',
#  'voltage_718.0s',
#  'voltage_719.0s',
#  'voltage_720.0s',
#  'voltage_721.0s',
#  'voltage_722.0s',
#  'voltage_723.0s',
#  'voltage_724.0s',
#  'voltage_725.0s',
#  'voltage_726.0s',
#  'voltage_727.0s',
#  'voltage_728.0s',
#  'voltage_729.0s',
#  'voltage_730.0s',
#  'voltage_731.0s',
#  'voltage_732.0s',
#  'voltage_733.0s',
#  'voltage_734.0s',
#  'voltage_735.0s',
#  'voltage_736.0s',
#  'voltage_737.0s',
#  'voltage_738.0s',
#  'voltage_739.0s',
#  'voltage_740.0s',
#  'voltage_741.0s',
#  'voltage_742.0s',
#  'voltage_743.0s',
#  'voltage_744.0s',
#  'voltage_745.0s',
#  'voltage_746.0s',
#  'voltage_747.0s',
#  'voltage_748.0s',
#  'voltage_749.0s',
#  'voltage_750.0s',
#  'voltage_751.0s',
#  'voltage_752.0s',
#  'voltage_753.0s',
#  'voltage_754.0s',
#  'voltage_755.0s',
#  'voltage_756.0s',
#  'voltage_757.0s',
#  'voltage_758.0s',
#  'voltage_759.0s',
#  'voltage_760.0s',
#  'voltage_761.0s',
#  'voltage_762.0s',
#  'voltage_763.0s',
#  'voltage_764.0s',
#  'voltage_765.0s',
#  'voltage_766.0s',
#  'voltage_767.0s',
#  'voltage_768.0s',
#  'voltage_769.0s',
#  'voltage_770.0s',
#  'voltage_771.0s',
#  'voltage_772.0s',
#  'voltage_773.0s',
#  'voltage_774.0s',
#  'voltage_775.0s',
#  'voltage_776.0s',
#  'voltage_777.0s',
#  'voltage_778.0s',
#  'voltage_779.0s',
#  'voltage_780.0s',
#  'voltage_781.0s',
#  'voltage_782.0s',
#  'voltage_783.0s',
#  'voltage_784.0s',
#  'voltage_785.0s',
#  'voltage_786.0s',
#  'voltage_787.0s',
#  'voltage_788.0s',
#  'voltage_789.0s',
#  'voltage_790.0s',
#  'voltage_791.0s',
#  'voltage_792.0s',
#  'voltage_793.0s',
#  'voltage_794.0s',
#  'voltage_795.0s',
#  'voltage_796.0s',
#  'voltage_797.0s',
#  'voltage_798.0s',
#  'voltage_799.0s',
#  'voltage_800.0s',
#  'voltage_801.0s',
#  'voltage_802.0s',
#  'voltage_803.0s',
#  'voltage_804.0s',
#  'voltage_805.0s',
#  'voltage_806.0s',
#  'voltage_807.0s',
#  'voltage_808.0s',
#  'voltage_809.0s',
#  'voltage_810.0s',
#  'voltage_811.0s',
#  'voltage_812.0s',
#  'voltage_813.0s',
#  'voltage_814.0s',
#  'voltage_815.0s',
#  'voltage_816.0s',
#  'voltage_817.0s',
#  'voltage_818.0s',
#  'voltage_819.0s',
#  'voltage_820.0s',
#  'voltage_821.0s',
#  'voltage_822.0s',
#  'voltage_823.0s',
#  'voltage_824.0s',
#  'voltage_825.0s',
#  'voltage_826.0s',
#  'voltage_827.0s',
#  'voltage_828.0s',
#  'voltage_829.0s',
#  'voltage_830.0s',
#  'voltage_831.0s',
#  'voltage_832.0s',
#  'voltage_833.0s',
#  'voltage_834.0s',
#  'voltage_835.0s',
#  'voltage_836.0s',
#  'voltage_837.0s',
#  'voltage_838.0s',
#  'voltage_839.0s',
#  'voltage_840.0s',
#  'voltage_841.0s',
#  'voltage_842.0s',
#  'voltage_843.0s',
#  'voltage_844.0s',
#  'voltage_845.0s',
#  'voltage_846.0s',
#  'voltage_847.0s',
#  'voltage_848.0s',
#  'voltage_849.0s',
#  'voltage_850.0s',
#  'voltage_851.0s',
#  'voltage_852.0s',
#  'voltage_853.0s',
#  'voltage_854.0s',
#  'voltage_855.0s',
#  'voltage_856.0s',
#  'voltage_857.0s',
#  'voltage_858.0s',
#  'voltage_859.0s',
#  'voltage_860.0s',
#  'voltage_861.0s',
#  'voltage_862.0s',
#  'voltage_863.0s',
#  'voltage_864.0s',
#  'voltage_865.0s',
#  'voltage_866.0s',
#  'voltage_867.0s',
#  'voltage_868.0s',
#  'voltage_869.0s',
#  'voltage_870.0s',
#  'voltage_871.0s',
#  'voltage_872.0s',
#  'voltage_873.0s',
#  'voltage_874.0s',
#  'voltage_875.0s',
#  'voltage_876.0s',
#  'voltage_877.0s',
#  'voltage_878.0s',
#  'voltage_879.0s',
#  'voltage_880.0s',
#  'voltage_881.0s',
#  'voltage_882.0s',
#  'voltage_883.0s',
#  'voltage_884.0s',
#  'voltage_885.0s',
#  'voltage_886.0s',
#  'voltage_887.0s',
#  'voltage_888.0s',
#  'voltage_889.0s',
#  'voltage_890.0s',
#  'voltage_891.0s',
#  'voltage_892.0s',
#  'voltage_893.0s',
#  'voltage_894.0s',
#  'voltage_895.0s',
#  'voltage_896.0s',
#  'voltage_897.0s',
#  'voltage_898.0s',
#  'voltage_899.0s',
#  'current_0.0s',
#  'current_1.0s',
#  'current_2.0s',
#  'current_3.0s',
#  'current_4.0s',
#  'current_5.0s',
#  'current_6.0s',
#  'current_7.0s',
#  'current_8.0s',
#  'current_9.0s',
#  'current_10.0s',
#  'current_11.0s',
#  'current_12.0s',
#  'current_13.0s',
#  'current_14.0s',
#  'current_15.0s',
#  'current_16.0s',
#  'current_17.0s',
#  'current_18.0s',
#  'current_19.0s',
#  'current_20.0s',
#  'current_21.0s',
#  'current_22.0s',
#  'current_23.0s',
#  'current_24.0s',
#  'current_25.0s',
#  'current_26.0s',
#  'current_27.0s',
#  'current_28.0s',
#  'current_29.0s',
#  'current_30.0s',
#  'current_31.0s',
#  'current_32.0s',
#  'current_33.0s',
#  'current_34.0s',
#  'current_35.0s',
#  'current_36.0s',
#  'current_37.0s',
#  'current_38.0s',
#  'current_39.0s',
#  'current_40.0s',
#  'current_41.0s',
#  'current_42.0s',
#  'current_43.0s',
#  'current_44.0s',
#  'current_45.0s',
#  'current_46.0s',
#  'current_47.0s',
#  'current_48.0s',
#  'current_49.0s',
#  'current_50.0s',
#  'current_51.0s',
#  'current_52.0s',
#  'current_53.0s',
#  'current_54.0s',
#  'current_55.0s',
#  'current_56.0s',
#  'current_57.0s',
#  'current_58.0s',
#  'current_59.0s',
#  'current_60.0s',
#  'current_61.0s',
#  'current_62.0s',
#  'current_63.0s',
#  'current_64.0s',
#  'current_65.0s',
#  'current_66.0s',
#  'current_67.0s',
#  'current_68.0s',
#  'current_69.0s',
#  'current_70.0s',
#  'current_71.0s',
#  'current_72.0s',
#  'current_73.0s',
#  'current_74.0s',
#  'current_75.0s',
#  'current_76.0s',
#  'current_77.0s',
#  'current_78.0s',
#  'current_79.0s',
#  'current_80.0s',
#  'current_81.0s',
#  'current_82.0s',
#  'current_83.0s',
#  'current_84.0s',
#  'current_85.0s',
#  'current_86.0s',
#  'current_87.0s',
#  'current_88.0s',
#  'current_89.0s',
#  'current_90.0s',
#  'current_91.0s',
#  'current_92.0s',
#  'current_93.0s',
#  'current_94.0s',
#  'current_95.0s',
#  'current_96.0s',
#  ...]

# %%
A = torch.load('../../results/fixed/bootstrap_results_A.pth', weights_only=False)


fig, ax = plt.subplots(figsize=(6, 4))
plot_true_vs_pred_axis(ax, "Charge_Depleting", "soc_mean", A, n_splits=50, title=f"Dataset A")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       1 A = torch.load('../../results/fixed/bootstrap_results_A.pth', weights_only=False)
#       4 fig, ax = plt.subplots(figsize=(6, 4))
# ----> 5 plot_true_vs_pred_axis(ax, "Charge_Depleting", "soc_mean", A, n_splits=50, title=f"Dataset A")
#
# Cell In[4], line 14, in plot_true_vs_pred_axis(ax, pulse, target, result_dict, color, n_splits, title)
#      10 ax.axline( (df[target].min(), df[target].min()),
#      11                    (df[target].max(), df[target].max()),
#      12                  linestyle='dashed', color='gray')
#      13 ax.set_title(title)
# ---> 14 ax.annotate("r^2: {:.3f}".format(r2_score(df[target], average_pred)), xy=(0.05, 0.9), xycoords='axes fraction', fontsize=8)
#
# File c:\Users\etenney\AppData\Local\anaconda3\envs\battery_pulse_diagnostics\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\etenney\AppData\Local\anaconda3\envs\battery_pulse_diagnostics\Lib\site-packages\sklearn\metrics\_regression.py:1276, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#    1152 """:math:`R^2` (coefficient of determination) regression score function.
#    1153
#    1154 Best possible score is 1.0 and it can be negative (because the
#    (...)   1269 -inf
#    1270 """
#    1271 xp, _, device_ = get_namespace_and_device(
#    1272     y_true, y_pred, sample_weight, multioutput
#    1273 )
#    1275 _, y_true, y_pred, sample_weight, multioutput = (
# -> 1276     _check_reg_targets_with_floating_dtype(
#    1277         y_true, y_pred, sample_weight, multioutput, xp=xp
#    1278     )
#    1279 )
#    1281 if _num_samples(y_pred) < 2:
#    1282     msg = "R^2 score is not well-defined with less than two samples."
#
# File c:\Users\etenney\AppData\Local\anaconda3\envs\battery_pulse_diagnostics\Lib\site-packages\sklearn\metrics\_regression.py:209, in _check_reg_targets_with_floating_dtype(y_true, y_pred, sample_weight, multioutput, xp)
#     160 """Ensures y_true, y_pred, and sample_weight correspond to same regression task.
#     161
#     162 Extends `_check_reg_targets` by automatically selecting a suitable floating-point
#    (...)    205     correct keyword.
#     206 """
#     207 dtype_name = _find_matching_floating_dtype(y_true, y_pred, sample_weight, xp=xp)
# --> 209 y_type, y_true, y_pred, sample_weight, multioutput = _check_reg_targets(
#     210     y_true, y_pred, sample_weight, multioutput, dtype=dtype_name, xp=xp
#     211 )
#     213 return y_type, y_true, y_pred, sample_weight, multioutput
#
# File c:\Users\etenney\AppData\Local\anaconda3\envs\battery_pulse_diagnostics\Lib\site-packages\sklearn\metrics\_regression.py:116, in _check_reg_targets(y_true, y_pred, sample_weight, multioutput, dtype, xp)
#     114 check_consistent_length(y_true, y_pred, sample_weight)
#     115 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 116 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     117 if sample_weight is not None:
#     118     sample_weight = _check_sample_weight(sample_weight, y_true, dtype=dtype)
#
# File c:\Users\etenney\AppData\Local\anaconda3\envs\battery_pulse_diagnostics\Lib\site-packages\sklearn\utils\validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\etenney\AppData\Local\anaconda3\envs\battery_pulse_diagnostics\Lib\site-packages\sklearn\utils\validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File c:\Users\etenney\AppData\Local\anaconda3\envs\battery_pulse_diagnostics\Lib\site-packages\sklearn\utils\validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
A = torch.load('../../results/partial_charge/bootstrap_results_A.pth', weights_only=False)

pulses = [
    "Rate_Test_C/2",
    "PsRP_1_C/2",
    "PsRP_2_C/2",
]
targets = [
    "C/2 discharge capacity",
    "soc_mean",
]

fig, ax = plt.subplots(2,3, figsize=(18, 10))
ax = ax.flatten()
for i in range(3):
    plot_true_vs_pred_axis(ax[i], pulses[i], targets[0], A, n_splits=50, title=f"{pulses[i]}, {targets[0]}, Dataset A")
for i in range(3):
    plot_true_vs_pred_axis(ax[i+3], pulses[i], targets[1], A, n_splits=50, title=f"{pulses[i]}, {targets[1]}, Dataset A")
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(6, 4))
A = torch.load('../../results/partial_charge/bootstrap_results_A.pth', weights_only=False)
plot_true_vs_pred_axis(ax, "Rate_Test_C/2", "soc_mean", A, n_splits=50, title=f"Dataset A")

# %%
def get_metrics_all_targets(results_dict_list):
    """
    Construct a wide format df for plotting convenience
    """
    metrics = {
                'r2': [],
                'mae': [],
                'mape': [],
                'Target': [],
                'Cell ID': [],
                'Pulse Type': [],
              }
    for results_dict_soc in results_dict_list:
        for key in results_dict_soc:
            if 'features' in key:
                continue
                
            target, pulse = key.split(', ')
            if target == 'Post 1C charge relaxation fit MSE':
                continue
            df = results_dict_soc[key]
            cell_id = df['cell_id'][0][0]

            for run in range(50):
                test_subset = df[df[run].notna()]
                r2 = r2_score(test_subset[target], test_subset[run])
                mae = mean_absolute_error(test_subset[target], test_subset[run])
                mape = mean_absolute_percentage_error(test_subset[target], test_subset[run])         
                metrics[f"r2"].append(r2)
                metrics[f"mae"].append(mae)
                metrics["mape"].append(mape)
                
            metrics['Target'] += [target] * 50
            metrics['Cell ID'] += [cell_id] * 50
            metrics['Pulse Type'] += [pulse] * 50

    return pd.DataFrame(metrics)

# %%
A_test = torch.load('../../results/partial_charge/soc_prediction/bootstrap_results_A.pth', weights_only=False)
B_test = torch.load('../../results/partial_charge/soc_prediction/bootstrap_results_B.pth', weights_only=False)
C_test = torch.load('../../results/partial_charge/soc_prediction2/bootstrap_results_C.pth', weights_only=False)
D_test = torch.load('../../results/partial_charge/soc_prediction/bootstrap_results_D.pth', weights_only=False)

metrics = get_metrics_all_targets([A_test, B_test, C_test, D_test])

fig, ax = plt.subplots(figsize=(12, 5))
pulses = [
    "Charge_Depleting",
    "Charge_Sustaining",
    "Rate_Test_C/2",
    "Rate_Test_1C",
    "PsRP_1_C/2",
    "PsRP_1_1C",
    "PsRP_2_C/2",
    "PsRP_2_1C",
]
def t(metrics, target, pulses=None):
    metrics = metrics[metrics['Target'] == target]
    if pulses is not None:
        metrics = metrics[metrics['Pulse Type'].isin(pulses)]
    return metrics
sns.boxplot(t(metrics, "soc_mean", pulses), x='Cell ID', y='mae', hue='Pulse Type', ax=ax)
ax.set_title("MAE for SOC prediction")
# Out:
# Text(0.5, 1.0, 'MAE for SOC prediction')

# %%
A_discharge = torch.load('../../results/partial_charge/c3_prediction/bootstrap_results_A.pth', weights_only=False)
B_discharge = torch.load('../../results/partial_charge/c3_prediction/bootstrap_results_B.pth', weights_only=False)
C_discharge = torch.load('../../results/partial_charge/c3_prediction/bootstrap_results_C.pth', weights_only=False)
D_discharge = torch.load('../../results/partial_charge/c3_prediction/bootstrap_results_D.pth', weights_only=False)

metrics_discharge = get_metrics_all_targets([A_discharge, B_discharge, C_discharge, D_discharge])
fig, ax = plt.subplots(figsize=(12, 5))
sns.boxplot(t(metrics_discharge, "C/3 discharge capacity", pulses), x='Cell ID', y='mape', hue='Pulse Type', ax=ax)
ax.set_title("MAPE for C/3 Discharge Capacity prediction")
ax.set_yscale('log')

# %%
C_test = torch.load('../../results/partial_charge/test/bootstrap_results_C.pth', weights_only=False)
metrics_test = get_metrics_all_targets([C_test])
fig, ax = plt.subplots(figsize=(12, 5))
sns.boxplot(t(metrics_test, "soc_mean", pulses), x='Cell ID', y='mae', hue='Pulse Type', ax=ax)
ax.set_title("MAE for SOC Mean prediction")

# %%
df = A_test[list(A_test.keys())[0]]
df
# Out:
#        soc_initial  soc_final split_type  measurement_id cell_id  \
# 0         0.952983   0.949018    testing               0    B_01
# 1         0.901729   0.897762    testing               0    B_01
# 2         0.850396   0.846425    testing               0    B_01
# 3         0.798988   0.794994    testing               0    B_01
# 4         0.747398   0.743398    testing               0    B_01
# ...            ...        ...        ...             ...     ...
# 19681     0.051111   0.026106   training              27    B_08
# 19682     0.072144   0.051825   training              27    B_08
# 19683     0.066901   0.044253   training              27    B_08
# 19684     0.083678   0.067655   training              27    B_08
# 19685     0.033373   0.013291   training              27    B_08
#
#        temperature_ambient  C/10 discharge capacity  C/5 discharge capacity  \
# 0                     30.0                    42.00                   41.19
# 1                     30.0                    42.00                   41.19
# 2                     30.0                    42.00                   41.19
# 3                     30.0                    42.00                   41.19
# 4                     30.0                    42.00                   41.19
# ...                    ...                      ...                     ...
# 19681                 30.5                    47.69                   47.19
# 19682                 30.5                    47.69                   47.19
# 19683                 30.5                    47.69                   47.19
# 19684                 30.5                    47.69                   47.19
# 19685                 30.5                    47.69                   47.19
#
#        C/3 discharge capacity  C/2 discharge capacity  ...        40  \
# 0                       40.82                   40.37  ...  0.895048
# 1                       40.82                   40.37  ...  0.882615
# 2                       40.82                   40.37  ...  0.911146
# 3                       40.82                   40.37  ...  0.801839
# 4                       40.82                   40.37  ...  0.772167
# ...                       ...                     ...  ...       ...
# 19681                   46.80                   46.63  ...       NaN
# 19682                   46.80                   46.63  ...       NaN
# 19683                   46.80                   46.63  ...       NaN
# 19684                   46.80                   46.63  ...       NaN
# 19685                   46.80                   46.63  ...       NaN
#
#              41        42        43        44        45        46        47  \
# 0      0.936778  0.944533  0.964087  0.971159  0.946053  0.969003  0.936374
# 1      0.929906  0.917788  0.938500  0.949159  0.945514  0.963887  0.915748
# 2      0.934967  0.866568  0.934805  0.905144  0.944480  0.933687  0.917145
# 3      0.855289  0.910505  0.856796  0.843481  0.932266  0.908261  0.906011
# 4      0.790138  0.800543  0.808686  0.739948  0.794719  0.772627  0.768227
# ...         ...       ...       ...       ...       ...       ...       ...
# 19681       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19682       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19683       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19684       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19685       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#              48        49
# 0      0.973003  0.934705
# 1      0.957156  0.942834
# 2      0.927033  0.945289
# 3      0.893957  0.917584
# 4      0.799034  0.698327
# ...         ...       ...
# 19681       NaN       NaN
# 19682       NaN       NaN
# 19683       NaN       NaN
# 19684       NaN       NaN
# 19685       NaN       NaN
#
# [19686 rows x 75 columns]

# %%
THRESHOLDS_1C = {
    "A": 3.6e-6,
    "B": 0.0000165,
    "C": 2.5e-06,
}
THRESHOLDS_C_2 = {
    "A": 3.6e-6,
    "B": 0.0000275,
    "C": 5.7e-06,
}

def make_binary(
    df: pd.DataFrame, original_target: str, threshold: float, tag: str = "_outlier"
):
    """
    Binarize a continuous feature by setting all values
    less than a given threshold to 0 and all values above
    the given threshold to 1. Add the binarized feature
    as a new column in df, with the suffix `tag` appended
    to the original name.

    Args:
        df (pd.DataFrame): Set of all data
        original_target (str): Name of variable
                               in df to binarize
        threshold (float): Binarization threshold
        tag (str): Suffix for new binarized feature.

    Return:
        pd.DataFrame
    """
    target = f"{original_target}{tag}"
    df.loc[df[original_target] >= threshold, target] = 1
    df.loc[df[original_target] < threshold, target] = 0
    return df

def filter_cell_type(df: pd.DataFrame, cell_type: str):
    """
    Filter dataframe for cell type A, B, or C.

    Args:
        df (pd.DataFrame):  Dataframe to filter.
                            Expected to have column "cell_id".
        cell_type (str):    Cell type identifier to filter for.

    Returns:
        pd.DataFrame: df filtered for rows where
                      "cell_id" starts with `cell_type`.
    """
    cell_df = df[df["cell_id"].str.startswith(cell_type)]
    return cell_df.reset_index(drop=True)

def load_partial_charge_data(filename: str = "data_partial_charge_for_ml.h5", cell_type: str = None):
    """
    Process data from h5 file into dictionary where keys are
    pulse types and values are dataframes of features/targets.

    Args:
        filename:   Path to h5 file generated by 05_process_data_for_ml.py
        cell_type:  One of {None, "A", "B", "C"}. If provided,
                    filters data only for that cell type.

    Return:
        tests:      Dictionary of feature/target data where each
                    key is a pulse measurement type.
    """

    data = pd.HDFStore(filename)

    charge_depleting = data.get("Charge_Depleting")
    charge_sustaining = data.get("Charge_Sustaining")
    rate_test_C2 = data.get("Rate_Test_C/2")
    rate_test_1C = data.get("Rate_Test_1C")
    psrp_1_C2 = data.get("PsRP_1_C/2")
    psrp_1_1C = data.get("PsRP_1_1C")
    psrp_2_C2 = data.get("PsRP_2_C/2")
    psrp_2_1C = data.get("PsRP_2_1C")

    if cell_type is not None:
        charge_depleting = filter_cell_type(charge_depleting, cell_type)
        charge_sustaining = filter_cell_type(charge_sustaining, cell_type)
        rate_test_C2 = filter_cell_type(rate_test_C2, cell_type)
        rate_test_1C = filter_cell_type(rate_test_1C, cell_type)
        psrp_1_C2 = filter_cell_type(psrp_1_C2, cell_type)
        psrp_1_1C = filter_cell_type(psrp_1_1C, cell_type)
        psrp_2_C2 = filter_cell_type(psrp_2_C2, cell_type)
        psrp_2_1C = filter_cell_type(psrp_2_1C, cell_type)

    # get 1/10 of the randomized samples for use in the model.
    depleting_testing = charge_depleting[charge_depleting['split_type'] == "testing"]
    # depleting_training = charge_depleting.groupby(by='measurement_id').sample(frac=0.1, random_state=42)
    depleting_training = charge_depleting[charge_depleting['split_type'] == "training"]
    charge_depleting = pd.concat([depleting_testing, depleting_training])
    charge_depleting.reset_index(drop=True, inplace=True)
    sustaining_testing = charge_sustaining[charge_sustaining['split_type'] == "testing"]
    # sustaining_training = charge_sustaining.groupby(by='measurement_id').sample(frac=0.1, random_state=42)
    sustaining_training = charge_sustaining[charge_sustaining['split_type'] == "training"]
    charge_sustaining = pd.concat([sustaining_testing, sustaining_training])
    charge_sustaining.reset_index(drop=True, inplace=True)
    rate_test_C2 = rate_test_C2.groupby(by='measurement_id').sample(frac=0.1, random_state=42)
    rate_test_C2.reset_index(drop=True, inplace=True)
    rate_test_1C = rate_test_1C.groupby(by='measurement_id').sample(frac=0.1, random_state=42)
    rate_test_1C.reset_index(drop=True, inplace=True)
    psrp_1_C2 = psrp_1_C2.groupby(by='measurement_id').sample(frac=0.1, random_state=42)
    psrp_1_C2.reset_index(drop=True, inplace=True)
    psrp_1_1C = psrp_1_1C.groupby(by='measurement_id').sample(frac=0.1, random_state=42)
    psrp_1_1C.reset_index(drop=True, inplace=True)
    psrp_2_C2 = psrp_2_C2.groupby(by='measurement_id').sample(frac=0.1, random_state=42)
    psrp_2_C2.reset_index(drop=True, inplace=True)
    psrp_2_1C = psrp_2_1C.groupby(by='measurement_id').sample(frac=0.1, random_state=42)
    psrp_2_1C.reset_index(drop=True, inplace=True)

    print(f"charge depleting size: {charge_depleting.shape}")
    print(f"charge sustaining size: {charge_sustaining.shape}")
    print(f"rate test C/2 size: {rate_test_C2.shape}")
    print(f"rate test 1C size: {rate_test_1C.shape}")
    print(f"PsRP 1 C/2 size: {psrp_1_C2.shape}")
    print(f"PsRP 1 1C size: {psrp_1_1C.shape}")
    print(f"PsRP 2 C/2 size: {psrp_2_C2.shape}")
    print(f"PsRP 2 1C size: {psrp_2_1C.shape}")
    #does this sample 10% of measurement ids? or the intended 10% of random samples

    tests = {
        "Charge_Depleting": charge_depleting,
        "Charge_Sustaining": charge_sustaining,
        "Rate_Test_C/2": rate_test_C2,
        "Rate_Test_1C": rate_test_1C,
        "PsRP_1_C/2": psrp_1_C2,
        "PsRP_1_1C": psrp_1_1C,
        "PsRP_2_C/2": psrp_2_C2,
        "PsRP_2_1C": psrp_2_1C,
    }

    data.close()

    ### Add some additional features and targets ###
    for test in tests:

        # Give each row a unique "sample_id"
        tests[test]["sample_id"] = tests[test].index

        # Add polarization feature (V - V0)
        if test != "DCIR":
            voltage_cols = tests[test].filter(regex="voltage").columns
            for v in voltage_cols:
                tests[test][f"polarization_{v.split('_')[1]}"] = (
                    tests[test][v] - tests[test][voltage_cols[0]]
                )

        # Make Excess electrolyte categorical
        # le = LabelEncoder()
        # mask = tests[test]["Excess electrolyte"].isna()
        # tests[test]["Excess electrolyte"] = le.fit_transform(
        #     tests[test]["Excess electrolyte"]
        # )
        # tests[test]["Excess electrolyte"][mask] = np.nan

        # Add C/3 discharge * SOC target
        c_3_discharge = tests[test]["C/3 discharge capacity"]
        soc = tests[test]["soc_mean"]
        tests[test]["C/3 discharge capacity * SOC"] = c_3_discharge * soc

        # Binarize safety to use for binary classification
        if cell_type is not None and cell_type != "D":
            # Using post-1C charge
            original_target = "Post 1C charge relaxation fit MSE"
            tests[test] = make_binary(
                tests[test],
                original_target,
                threshold=THRESHOLDS_1C[cell_type],
                tag="_outlier",
            )

            # Using post-2C charge
            original_target = "Post C/2 charge relaxation fit MSE"
            tests[test] = make_binary(
                tests[test],
                original_target,
                threshold=THRESHOLDS_C_2[cell_type],
                tag="_outlier",
            )

            # Using post-1C OR post-2C charge
            tests[test]["Post 1C or Post C/2_outlier"] = tests[test][
                "Post 1C charge relaxation fit MSE_outlier"
            ].astype(int) | tests[test][
                "Post C/2 charge relaxation fit MSE_outlier"
            ].astype(
                int
            )

        # Set up categorical bins ("good", "okay", and "bad") for capacity values
        thresholds = {
            "A": [0.80 * 64, 0.90 * 64],
            "B": [0.70 * 66, 0.80 * 66],
            "C": [0.80 * 26, 0.90 * 26],
            "D": [0.80 * 2.5, 0.90 * 2.5],
        }
        if cell_type is not None:
            for original_target in ["1C discharge capacity", "C/3 discharge capacity"]:
                tests[test][f"{original_target}_3bins"] = np.digitize(
                    tests[test][original_target], bins=thresholds[cell_type]
                )

    return tests

# %%
tests = load_partial_charge_data(filename="../../data/data_partial_charge_for_ml.h5" ,cell_type="C")

target = "soc_mean"

df = tests["Charge_Sustaining"]
df = df[df[target].notna()]

train_fixed = df[df["split_type"] == "training"]
idx_test_fixed = df[df["split_type"] == "testing"].index.to_numpy()

idx_train = train_fixed.groupby(by='measurement_id').sample(frac=0.1, random_state=42).index.to_numpy()
idx_test = idx_test_fixed

train, test = df.loc[idx_train], df.loc[idx_test]


regex="voltage|P/I|polarization|current|temperature|power"

train
# Out:
# charge depleting size: (76755, 387)
# charge sustaining size: (4794, 5424)
# rate test C/2 size: (641, 2723)
# rate test 1C size: (628, 1463)
# PsRP 1 C/2 size: (686, 2723)
# PsRP 1 1C size: (646, 1463)
# PsRP 2 C/2 size: (695, 2723)
# PsRP 2 1C size: (640, 1463)
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:161: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test]["C/3 discharge capacity * SOC"] = c_3_discharge * soc
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df[original_target] >= threshold, target] = 1
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df[original_target] >= threshold, target] = 1
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:184: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test]["Post 1C or Post C/2_outlier"] = tests[test][
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:201: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"{original_target}_3bins"] = np.digitize(
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:201: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"{original_target}_3bins"] = np.digitize(
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# ...
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"polarization_{v.split('_')[1]}"] = (
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:161: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test]["C/3 discharge capacity * SOC"] = c_3_discharge * soc
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df[original_target] >= threshold, target] = 1
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df[original_target] >= threshold, target] = 1
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:184: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test]["Post 1C or Post C/2_outlier"] = tests[test][
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:201: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"{original_target}_3bins"] = np.digitize(
# C:\Users\etenney\AppData\Local\Temp\1\ipykernel_46316\3710430857.py:201: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   tests[test][f"{original_target}_3bins"] = np.digitize(
#       soc_mean  soc_initial  soc_final split_type  voltage_  0.0s  \
# 107  -0.354769    -0.363597  -0.319499   training           3.301
# 133  -0.330829    -0.358065  -0.312856   training           3.286
# 124  -0.325855    -0.338102  -0.381148   training           3.261
# 139  -0.362709    -0.312856  -0.381678   training           3.259
# 111  -0.337151    -0.362714  -0.326649   training           3.289
# ...        ...          ...        ...        ...             ...
# 4762  0.493136     0.483551   0.532732   training           3.708
# 4780  0.511850     0.520263   0.481486   training           3.775
# 4792  0.515222     0.483699   0.499508   training           3.739
# 4767  0.515997     0.501058   0.496998   training           3.758
# 4750  0.493915     0.518624   0.481258   training           3.744
#
#       voltage_  4.0s  voltage_  8.0s  voltage_ 12.0s  voltage_ 16.0s  \
# 107            3.307           3.301           3.306           3.306
# 133            3.280           3.276           3.271           3.267
# 124            3.257           3.253           3.250           3.248
# 139            3.260           3.249           3.260           3.260
# 111            3.290           3.296           3.299           3.303
# ...              ...             ...             ...             ...
# 4762           3.704           3.701           3.700           3.699
# 4780           3.777           3.780           3.785           3.790
# 4792           3.750           3.751           3.751           3.738
# 4767           3.758           3.763           3.770           3.770
# 4750           3.742           3.739           3.752           3.752
#
#       voltage_ 20.0s  ...  polarization_1795.0s  polarization_1797.0s  \
# 107            3.305  ...                   NaN                   NaN
# 133            3.262  ...                   NaN                   NaN
# 124            3.245  ...                   NaN                   NaN
# 139            3.261  ...                   NaN                   NaN
# 111            3.307  ...                   NaN                   NaN
# ...              ...  ...                   ...                   ...
# 4762           3.718  ...                   NaN                   NaN
# 4780           3.794  ...                   NaN                   NaN
# 4792           3.738  ...                   NaN                   NaN
# 4767           3.771  ...                   NaN                   NaN
# 4750           3.755  ...                   NaN                   NaN
#
#       polarization_1798.0s  polarization_1799.0s  \
# 107                    NaN                   NaN
# 133                    NaN                   NaN
# 124                    NaN                   NaN
# 139                    NaN                   NaN
# 111                    NaN                   NaN
# ...                    ...                   ...
# 4762                   NaN                   NaN
# 4780                   NaN                   NaN
# 4792                   NaN                   NaN
# 4767                   NaN                   NaN
# 4750                   NaN                   NaN
#
#       C/3 discharge capacity * SOC  Post 1C charge relaxation fit MSE_outlier  \
# 107                      -9.135293                                        1.0
# 133                      -8.518842                                        1.0
# 124                      -8.390758                                        1.0
# 139                      -9.339746                                        1.0
# 111                      -8.681644                                        1.0
# ...                            ...                                        ...
# 4762                      9.438626                                        1.0
# 4780                      9.796800                                        1.0
# 4792                      9.861357                                        1.0
# 4767                      9.876184                                        1.0
# 4750                      9.453534                                        1.0
#
#       Post C/2 charge relaxation fit MSE_outlier  Post 1C or Post C/2_outlier  \
# 107                                          0.0                            1
# 133                                          0.0                            1
# 124                                          0.0                            1
# 139                                          0.0                            1
# 111                                          0.0                            1
# ...                                          ...                          ...
# 4762                                         1.0                            1
# 4780                                         1.0                            1
# 4792                                         1.0                            1
# 4767                                         1.0                            1
# 4750                                         1.0                            1
#
#       1C discharge capacity_3bins  C/3 discharge capacity_3bins
# 107                             2                             2
# 133                             2                             2
# 124                             2                             2
# 139                             2                             2
# 111                             2                             2
# ...                           ...                           ...
# 4762                            0                             0
# 4780                            0                             0
# 4792                            0                             0
# 4767                            0                             0
# 4750                            0                             0
#
# [470 rows x 7231 columns]

# %%
cols = train.filter(regex=regex).columns
grouped_cols = {}
for col in cols:
	prefix = col.split('_')[0]
	grouped_cols.setdefault(prefix, []).append(col)
grouped_cols.keys()
# Out:
# dict_keys(['voltage', 'current', 'power', 'temperature', 'polarization'])

# %%
train
# Out:
#       soc_mean  soc_initial  soc_final split_type  voltage_  0.0s  \
# 107  -0.354769    -0.363597  -0.319499   training           3.301
# 133  -0.330829    -0.358065  -0.312856   training           3.286
# 124  -0.325855    -0.338102  -0.381148   training           3.261
# 139  -0.362709    -0.312856  -0.381678   training           3.259
# 111  -0.337151    -0.362714  -0.326649   training           3.289
# ...        ...          ...        ...        ...             ...
# 4762  0.493136     0.483551   0.532732   training           3.708
# 4780  0.511850     0.520263   0.481486   training           3.775
# 4792  0.515222     0.483699   0.499508   training           3.739
# 4767  0.515997     0.501058   0.496998   training           3.758
# 4750  0.493915     0.518624   0.481258   training           3.744
#
#       voltage_  4.0s  voltage_  8.0s  voltage_ 12.0s  voltage_ 16.0s  \
# 107            3.307           3.301           3.306           3.306
# 133            3.280           3.276           3.271           3.267
# 124            3.257           3.253           3.250           3.248
# 139            3.260           3.249           3.260           3.260
# 111            3.290           3.296           3.299           3.303
# ...              ...             ...             ...             ...
# 4762           3.704           3.701           3.700           3.699
# 4780           3.777           3.780           3.785           3.790
# 4792           3.750           3.751           3.751           3.738
# 4767           3.758           3.763           3.770           3.770
# 4750           3.742           3.739           3.752           3.752
#
#       voltage_ 20.0s  ...  polarization_1795.0s  polarization_1797.0s  \
# 107            3.305  ...                   NaN                   NaN
# 133            3.262  ...                   NaN                   NaN
# 124            3.245  ...                   NaN                   NaN
# 139            3.261  ...                   NaN                   NaN
# 111            3.307  ...                   NaN                   NaN
# ...              ...  ...                   ...                   ...
# 4762           3.718  ...                   NaN                   NaN
# 4780           3.794  ...                   NaN                   NaN
# 4792           3.738  ...                   NaN                   NaN
# 4767           3.771  ...                   NaN                   NaN
# 4750           3.755  ...                   NaN                   NaN
#
#       polarization_1798.0s  polarization_1799.0s  \
# 107                    NaN                   NaN
# 133                    NaN                   NaN
# 124                    NaN                   NaN
# 139                    NaN                   NaN
# 111                    NaN                   NaN
# ...                    ...                   ...
# 4762                   NaN                   NaN
# 4780                   NaN                   NaN
# 4792                   NaN                   NaN
# 4767                   NaN                   NaN
# 4750                   NaN                   NaN
#
#       C/3 discharge capacity * SOC  Post 1C charge relaxation fit MSE_outlier  \
# 107                      -9.135293                                        1.0
# 133                      -8.518842                                        1.0
# 124                      -8.390758                                        1.0
# 139                      -9.339746                                        1.0
# 111                      -8.681644                                        1.0
# ...                            ...                                        ...
# 4762                      9.438626                                        1.0
# 4780                      9.796800                                        1.0
# 4792                      9.861357                                        1.0
# 4767                      9.876184                                        1.0
# 4750                      9.453534                                        1.0
#
#       Post C/2 charge relaxation fit MSE_outlier  Post 1C or Post C/2_outlier  \
# 107                                          0.0                            1
# 133                                          0.0                            1
# 124                                          0.0                            1
# 139                                          0.0                            1
# 111                                          0.0                            1
# ...                                          ...                          ...
# 4762                                         1.0                            1
# 4780                                         1.0                            1
# 4792                                         1.0                            1
# 4767                                         1.0                            1
# 4750                                         1.0                            1
#
#       1C discharge capacity_3bins  C/3 discharge capacity_3bins
# 107                             2                             2
# 133                             2                             2
# 124                             2                             2
# 139                             2                             2
# 111                             2                             2
# ...                           ...                           ...
# 4762                            0                             0
# 4780                            0                             0
# 4792                            0                             0
# 4767                            0                             0
# 4750                            0                             0
#
# [470 rows x 7231 columns]

# %%
A_discharge = torch.load('../../results/partial_charge/capacity_no_polarization/bootstrap_results_A.pth', weights_only=False)
B_discharge = torch.load('../../results/partial_charge/capacity_no_polarization/bootstrap_results_B.pth', weights_only=False)
C_discharge = torch.load('../../results/partial_charge/capacity_no_polarization/bootstrap_results_C.pth', weights_only=False)
D_discharge = torch.load('../../results/partial_charge/capacity_no_polarization/bootstrap_results_D.pth', weights_only=False)
results_dict_list = [A_discharge, B_discharge, C_discharge, D_discharge]
metrics_discharge = get_metrics_all_targets(results_dict_list)

fig, ax = plt.subplots(4,4,figsize=(16, 16))

pulses = [
    "Charge_Depleting",
    "Charge_Sustaining",
    "Rate_Test_C/2",
    # "Rate_Test_1C",
    "PsRP_1_C/2",
    # "PsRP_1_1C",
    # "PsRP_2_C/2",
    # "PsRP_2_1C",
]

for i in range(4):
    plot_true_vs_pred_axis(ax[i,0], pulses[i], "C/3 discharge capacity", A_discharge, n_splits=50, title=f"Dataset A, {pulses[i]}")
    plot_true_vs_pred_axis(ax[i,1], pulses[i], "C/3 discharge capacity", B_discharge, n_splits=50, title=f"Dataset B, {pulses[i]}")
    plot_true_vs_pred_axis(ax[i,2], pulses[i], "C/3 discharge capacity", C_discharge, n_splits=50, title=f"Dataset C, {pulses[i]}")
    plot_true_vs_pred_axis(ax[i,3], pulses[i], "C/3 discharge capacity", D_discharge, n_splits=50, title=f"Dataset D, {pulses[i]}")
fig.tight_layout()

# %%
A_discharge
# Out:
# {'C/3 discharge capacity, Charge_Depleting':        soc_mean  soc_initial  soc_final split_type  measurement_id cell_id  \
#  0      0.949258     0.951081   0.946950    testing              28    A_24
#  1      0.895962     0.897786   0.893650    testing              28    A_24
#  2      0.842565     0.844394   0.840248    testing              28    A_24
#  3      0.789038     0.790874   0.786715    testing              28    A_24
#  4      0.735297     0.737136   0.732964    testing              28    A_24
#  ...         ...          ...        ...        ...             ...     ...
#  30034  0.112800     0.128087   0.098837   training              76    A_24
#  30035  0.137577     0.149931   0.124443   training              76    A_24
#  30036  0.130922     0.142975   0.116312   training              76    A_24
#  30037  0.098254     0.112009   0.087386   training              76    A_24
#  30038  0.143683     0.156139   0.132296   training              76    A_24
#
#         temperature_ambient  C/10 discharge capacity  C/5 discharge capacity  \
#  0                     31.0                    64.34                   64.25
#  1                     31.0                    64.34                   64.25
#  2                     31.0                    64.34                   64.25
#  3                     31.0                    64.34                   64.25
#  4                     31.0                    64.34                   64.25
#  ...                    ...                      ...                     ...
#  30034                 46.0                    65.05                   64.70
#  30035                 46.0                    65.05                   64.70
#  30036                 46.0                    65.05                   64.70
#  30037                 46.0                    65.05                   64.70
#  30038                 46.0                    65.05                   64.70
#
#         C/2 discharge capacity  ...         40         41         42  \
#  0                       63.63  ...  57.246586  57.843105  59.174030
#  1                       63.63  ...  56.906582  58.897850  59.558586
#  2                       63.63  ...  56.859852  59.226078  60.398914
#  3                       63.63  ...  58.949169  59.284576  60.392387
#  4                       63.63  ...  55.639797  58.393784  60.670124
#  ...                       ...  ...        ...        ...        ...
#  30034                   64.51  ...        NaN        NaN        NaN
#  30035                   64.51  ...        NaN        NaN        NaN
#  30036                   64.51  ...        NaN        NaN        NaN
#  30037                   64.51  ...        NaN        NaN        NaN
#  30038                   64.51  ...        NaN        NaN        NaN
#
#                43         44         45         46         47         48  \
#  0      60.233608  58.072777  57.804020  57.742504  58.936020  62.345943
#  1      60.347225  58.137497  56.823898  58.712963  58.872025  60.452084
#  2      58.430752  57.561287  57.542767  57.906960  60.131054  60.824173
#  3      56.998730  58.835045  57.543797  57.413513  58.928570  61.745197
#  4      56.672363  58.459248  57.366310  60.869671  59.579758  61.043221
#  ...          ...        ...        ...        ...        ...        ...
#  30034        NaN        NaN        NaN        NaN        NaN        NaN
#  30035        NaN        NaN        NaN        NaN        NaN        NaN
#  30036        NaN        NaN        NaN        NaN        NaN        NaN
#  30037        NaN        NaN        NaN        NaN        NaN        NaN
#  30038        NaN        NaN        NaN        NaN        NaN        NaN
#
#                49
#  0      59.762566
#  1      58.908787
#  2      59.257668
#  3      59.329594
#  4      58.309032
#  ...          ...
#  30034        NaN
#  30035        NaN
#  30036        NaN
#  30037        NaN
#  30038        NaN
#
#  [30039 rows x 75 columns],
#  'C/3 discharge capacity, Charge_Depleting, features_per_iteration': [],
#  'C/3 discharge capacity, Charge_Sustaining':       soc_mean  soc_initial  soc_final split_type  measurement_id cell_id  \
#  0     0.301015    -0.315802  -0.320862    testing              28    A_24
#  1     0.437367    -0.450796  -0.459214    testing              29    A_06
#  2     0.297216    -0.311818  -0.316831    testing              30    A_10
#  3     0.299368    -0.314218  -0.319265    testing              31    A_11
#  4     0.326950    -0.348464  -0.355122    testing              32    A_15
#  ...        ...          ...        ...        ...             ...     ...
#  2494  0.576389    -0.589150  -0.632160   training              76    A_24
#  2495  0.580360    -0.604364  -0.565270   training              76    A_24
#  2496  0.584194    -0.611299  -0.576855   training              76    A_24
#  2497  0.576293    -0.588867  -0.630758   training              76    A_24
#  2498  0.622771    -0.564143  -0.644719   training              76    A_24
#
#        temperature_ambient  C/10 discharge capacity  C/5 discharge capacity  \
#  0                    31.0                    64.34                   64.25
#  1                    31.5                    63.51                   63.13
#  2                    31.0                    58.02                   57.80
#  3                    30.5                    59.08                   58.85
#  4                    29.0                    65.22                   64.99
#  ...                   ...                      ...                     ...
#  2494                 46.0                    65.05                   64.70
#  2495                 46.0                    65.05                   64.70
#  2496                 46.0                    65.05                   64.70
#  2497                 46.0                    65.05                   64.70
#  2498                 46.0                    65.05                   64.70
#
#        C/2 discharge capacity  ...         40         41         42         43  \
#  0                      63.63  ...  57.499825  56.581028  59.476654  56.689728
#  1                      62.73  ...  60.617634  57.184574  62.304955  58.981632
#  2                      57.52  ...  57.499825  56.581028  59.454018  56.689728
#  3                      58.55  ...  57.445881  56.682533  60.393677  55.846607
#  4                      64.11  ...  57.624016  57.173306  59.426819  57.924946
#  ...                      ...  ...        ...        ...        ...        ...
#  2494                   64.51  ...        NaN        NaN        NaN        NaN
#  2495                   64.51  ...        NaN        NaN        NaN        NaN
#  2496                   64.51  ...        NaN        NaN        NaN        NaN
#  2497                   64.51  ...        NaN        NaN        NaN        NaN
#  2498                   64.51  ...        NaN        NaN        NaN        NaN
#
#               44         45         46         47         48         49
#  0     57.226128  59.712997  58.219372  59.912094  60.018253  59.679672
#  1     57.142197  59.160290  58.143272  60.132984  60.099106  59.285179
#  2     57.226128  59.712997  58.237476  59.910061  60.018253  59.679672
#  3     57.307556  58.750065  58.128742  60.953377  59.971050  59.243164
#  4     57.217506  60.951519  57.874260  61.435101  60.384304  57.959049
#  ...         ...        ...        ...        ...        ...        ...
#  2494        NaN        NaN        NaN        NaN        NaN        NaN
#  2495        NaN        NaN        NaN        NaN        NaN        NaN
#  2496        NaN        NaN        NaN        NaN        NaN        NaN
#  2497        NaN        NaN        NaN        NaN        NaN        NaN
#  2498        NaN        NaN        NaN        NaN        NaN        NaN
#
#  [2499 rows x 75 columns],
#  'C/3 discharge capacity, Charge_Sustaining, features_per_iteration': [],
#  'C/3 discharge capacity, Rate_Test_C/2':      soc_mean  soc_initial  soc_final  measurement_id cell_id  \
#  0    0.205145     0.143976   0.265858              28    A_24
#  1    0.604507     0.543991   0.665253              28    A_24
#  2    0.766382     0.705792   0.827114              28    A_24
#  3    0.370889     0.309804   0.431632              28    A_24
#  4    0.516025     0.455203   0.576620              28    A_24
#  ..        ...          ...        ...             ...     ...
#  281  0.739043     0.642936   0.834807              76    A_24
#  282  0.698370     0.602615   0.794165              76    A_24
#  283  0.638436     0.541593   0.734748              76    A_24
#  284  0.201967     0.106372   0.298831              76    A_24
#  285  0.403913     0.307892   0.499581              76    A_24
#
#       temperature_ambient  C/10 discharge capacity  C/5 discharge capacity  \
#  0                   31.0                    64.34                   64.25
#  1                   31.0                    64.34                   64.25
#  2                   31.0                    64.34                   64.25
#  3                   31.0                    64.34                   64.25
#  4                   31.0                    64.34                   64.25
#  ..                   ...                      ...                     ...
#  281                 46.0                    65.05                   64.70
#  282                 46.0                    65.05                   64.70
#  283                 46.0                    65.05                   64.70
#  284                 46.0                    65.05                   64.70
#  285                 46.0                    65.05                   64.70
#
#       C/2 discharge capacity  1C discharge capacity  ...  40  41  42  43  44  \
#  0                     63.63                  62.78  ... NaN NaN NaN NaN NaN
#  1                     63.63                  62.78  ... NaN NaN NaN NaN NaN
#  2                     63.63                  62.78  ... NaN NaN NaN NaN NaN
#  3                     63.63                  62.78  ... NaN NaN NaN NaN NaN
#  4                     63.63                  62.78  ... NaN NaN NaN NaN NaN
#  ..                      ...                    ...  ...  ..  ..  ..  ..  ..
#  281                   64.51                  64.41  ... NaN NaN NaN NaN NaN
#  282                   64.51                  64.41  ... NaN NaN NaN NaN NaN
#  283                   64.51                  64.41  ... NaN NaN NaN NaN NaN
#  284                   64.51                  64.41  ... NaN NaN NaN NaN NaN
#  285                   64.51                  64.41  ... NaN NaN NaN NaN NaN
#
#              45  46  47  48  49
#  0    60.834923 NaN NaN NaN NaN
#  1    52.649303 NaN NaN NaN NaN
#  2    60.869827 NaN NaN NaN NaN
#  3    58.582687 NaN NaN NaN NaN
#  4    55.960999 NaN NaN NaN NaN
#  ..         ...  ..  ..  ..  ..
#  281        NaN NaN NaN NaN NaN
#  282        NaN NaN NaN NaN NaN
#  283        NaN NaN NaN NaN NaN
#  284        NaN NaN NaN NaN NaN
#  285        NaN NaN NaN NaN NaN
#
#  [286 rows x 74 columns],
#  'C/3 discharge capacity, Rate_Test_C/2, features_per_iteration': [],
#  'C/3 discharge capacity, Rate_Test_1C':      soc_mean  soc_initial  soc_final  measurement_id cell_id  \
#  0    0.795033     0.729792   0.859845              28    A_24
#  1    0.538081     0.473278   0.603114              28    A_24
#  2    0.143159     0.078335   0.208618              28    A_24
#  3    0.630237     0.565423   0.695137              28    A_24
#  4    0.458118     0.393303   0.523139              28    A_24
#  ..        ...          ...        ...             ...     ...
#  241  0.346504     0.259049   0.434298              75    A_23
#  242  0.260736     0.156265   0.364400              76    A_24
#  243  0.282931     0.178436   0.387159              76    A_24
#  244  0.169373     0.065274   0.273714              76    A_24
#  245  0.443056     0.338748   0.547427              76    A_24
#
#       temperature_ambient  C/10 discharge capacity  C/5 discharge capacity  \
#  0                   31.0                    64.34                   64.25
#  1                   31.0                    64.34                   64.25
#  2                   31.0                    64.34                   64.25
#  3                   31.0                    64.34                   64.25
#  4                   31.0                    64.34                   64.25
#  ..                   ...                      ...                     ...
#  241                 46.0                    50.85                   50.67
#  242                 46.0                    65.05                   64.70
#  243                 46.0                    65.05                   64.70
#  244                 46.0                    65.05                   64.70
#  245                 46.0                    65.05                   64.70
#
#       C/2 discharge capacity  1C discharge capacity  ...         40         41  \
#  0                     63.63                  62.78  ...        NaN  60.797894
#  1                     63.63                  62.78  ...        NaN  56.507023
#  2                     63.63                  62.78  ...        NaN  58.476704
#  3                     63.63                  62.78  ...        NaN  54.594639
#  4                     63.63                  62.78  ...        NaN  54.852810
#  ..                      ...                    ...  ...        ...        ...
#  241                   50.33                  50.08  ...  62.456112        NaN
#  242                   64.51                  64.41  ...        NaN        NaN
#  243                   64.51                  64.41  ...        NaN        NaN
#  244                   64.51                  64.41  ...        NaN        NaN
#  245                   64.51                  64.41  ...        NaN        NaN
#
#       42         43         44  45         46         47         48         49
#  0   NaN  59.404984        NaN NaN        NaN        NaN  63.076797        NaN
#  1   NaN  57.425980        NaN NaN        NaN        NaN  57.791832        NaN
#  2   NaN  53.831638        NaN NaN        NaN        NaN  55.104668        NaN
#  3   NaN  56.150101        NaN NaN        NaN        NaN  56.551968        NaN
#  4   NaN  56.901505        NaN NaN        NaN        NaN  58.616589        NaN
#  ..   ..        ...        ...  ..        ...        ...        ...        ...
#  241 NaN        NaN  58.348438 NaN        NaN  61.497444        NaN        NaN
#  242 NaN        NaN  61.297119 NaN  56.822323        NaN        NaN  58.310146
#  243 NaN        NaN  58.706326 NaN  55.113716        NaN        NaN  58.839573
#  244 NaN        NaN  61.025913 NaN  56.000237        NaN        NaN  54.816349
#  245 NaN        NaN  61.100327 NaN  60.681850        NaN        NaN  59.221935
#
#  [246 rows x 74 columns],
#  'C/3 discharge capacity, Rate_Test_1C, features_per_iteration': [],
#  'C/3 discharge capacity, PsRP_1_C/2':      soc_mean  soc_initial  soc_final  measurement_id cell_id  \
#  0    0.698698     0.637471   0.759962              28    A_24
#  1    0.846466     0.784157   0.908149              28    A_24
#  2    0.457080     0.395115   0.518633              28    A_24
#  3    0.080862     0.017095   0.142317              28    A_24
#  4    0.120649     0.059277   0.181808              28    A_24
#  ..        ...          ...        ...             ...     ...
#  289  0.667401     0.569821   0.764525              76    A_24
#  290  0.697747     0.600819   0.794846              76    A_24
#  291  0.689995     0.593282   0.786029              76    A_24
#  292  0.160447     0.062950   0.258149              76    A_24
#  293  0.178679     0.081196   0.276212              76    A_24
#
#       temperature_ambient  C/10 discharge capacity  C/5 discharge capacity  \
#  0                   31.0                    64.34                   64.25
#  1                   31.0                    64.34                   64.25
#  2                   31.0                    64.34                   64.25
#  3                   31.0                    64.34                   64.25
#  4                   31.0                    64.34                   64.25
#  ..                   ...                      ...                     ...
#  289                 46.0                    65.05                   64.70
#  290                 46.0                    65.05                   64.70
#  291                 46.0                    65.05                   64.70
#  292                 46.0                    65.05                   64.70
#  293                 46.0                    65.05                   64.70
#
#       C/2 discharge capacity  1C discharge capacity  ...  40  41  42  43  \
#  0                     63.63                  62.78  ... NaN NaN NaN NaN
#  1                     63.63                  62.78  ... NaN NaN NaN NaN
#  2                     63.63                  62.78  ... NaN NaN NaN NaN
#  3                     63.63                  62.78  ... NaN NaN NaN NaN
#  4                     63.63                  62.78  ... NaN NaN NaN NaN
#  ..                      ...                    ...  ...  ..  ..  ..  ..
#  289                   64.51                  64.41  ... NaN NaN NaN NaN
#  290                   64.51                  64.41  ... NaN NaN NaN NaN
#  291                   64.51                  64.41  ... NaN NaN NaN NaN
#  292                   64.51                  64.41  ... NaN NaN NaN NaN
#  293                   64.51                  64.41  ... NaN NaN NaN NaN
#
#              44         45  46  47  48  49
#  0    57.044220        NaN NaN NaN NaN NaN
#  1    57.319878        NaN NaN NaN NaN NaN
#  2    53.928970        NaN NaN NaN NaN NaN
#  3    58.577057        NaN NaN NaN NaN NaN
#  4    59.122604        NaN NaN NaN NaN NaN
#  ..         ...        ...  ..  ..  ..  ..
#  289        NaN  51.544357 NaN NaN NaN NaN
#  290        NaN  55.591583 NaN NaN NaN NaN
#  291        NaN  55.746082 NaN NaN NaN NaN
#  292        NaN  58.382496 NaN NaN NaN NaN
#  293        NaN  58.663925 NaN NaN NaN NaN
#
#  [294 rows x 74 columns],
#  'C/3 discharge capacity, PsRP_1_C/2, features_per_iteration': [],
#  'C/3 discharge capacity, PsRP_1_1C':      soc_mean  soc_initial  soc_final  measurement_id cell_id  \
#  0    0.512153     0.448019   0.577664              28    A_24
#  1    0.445946     0.382039   0.506373              28    A_24
#  2    0.482122     0.413031   0.547864              28    A_24
#  3    0.634919     0.570891   0.697935              28    A_24
#  4    0.255835     0.192103   0.316980              28    A_24
#  ..        ...          ...        ...             ...     ...
#  248  0.152700     0.065784   0.241386              75    A_23
#  249  0.370497     0.266806   0.475685              76    A_24
#  250  0.279886     0.176974   0.385353              76    A_24
#  251  0.467212     0.358268   0.572377              76    A_24
#  252  0.550577     0.447277   0.649303              76    A_24
#
#       temperature_ambient  C/10 discharge capacity  C/5 discharge capacity  \
#  0                   31.0                    64.34                   64.25
#  1                   31.0                    64.34                   64.25
#  2                   31.0                    64.34                   64.25
#  3                   31.0                    64.34                   64.25
#  4                   31.0                    64.34                   64.25
#  ..                   ...                      ...                     ...
#  248                 46.0                    50.85                   50.67
#  249                 46.0                    65.05                   64.70
#  250                 46.0                    65.05                   64.70
#  251                 46.0                    65.05                   64.70
#  252                 46.0                    65.05                   64.70
#
#       C/2 discharge capacity  1C discharge capacity  ...         40         41  \
#  0                     63.63                  62.78  ...        NaN  58.340260
#  1                     63.63                  62.78  ...        NaN  58.097351
#  2                     63.63                  62.78  ...        NaN  58.673794
#  3                     63.63                  62.78  ...        NaN  57.427933
#  4                     63.63                  62.78  ...        NaN  57.345013
#  ..                      ...                    ...  ...        ...        ...
#  248                   50.33                  50.08  ...  61.736870  59.931355
#  249                   64.51                  64.41  ...  60.319309        NaN
#  250                   64.51                  64.41  ...  61.799885        NaN
#  251                   64.51                  64.41  ...  51.779366        NaN
#  252                   64.51                  64.41  ...  60.163696        NaN
#
#              42  43  44         45  46         47         48  49
#  0          NaN NaN NaN        NaN NaN  55.539375        NaN NaN
#  1          NaN NaN NaN        NaN NaN  57.422871        NaN NaN
#  2          NaN NaN NaN        NaN NaN  60.939411        NaN NaN
#  3          NaN NaN NaN        NaN NaN  58.619148        NaN NaN
#  4          NaN NaN NaN        NaN NaN  58.682018        NaN NaN
#  ..         ...  ..  ..        ...  ..        ...        ...  ..
#  248        NaN NaN NaN  61.157192 NaN        NaN        NaN NaN
#  249  58.921124 NaN NaN        NaN NaN        NaN  57.327755 NaN
#  250  59.995739 NaN NaN        NaN NaN        NaN  58.919502 NaN
#  251  51.390892 NaN NaN        NaN NaN        NaN  52.158161 NaN
#  252  58.376617 NaN NaN        NaN NaN        NaN  59.397457 NaN
#
#  [253 rows x 74 columns],
#  'C/3 discharge capacity, PsRP_1_1C, features_per_iteration': [],
#  'C/3 discharge capacity, PsRP_2_C/2':      soc_mean  soc_initial  soc_final  measurement_id cell_id  \
#  0    0.401487     0.340202   0.461864              28    A_24
#  1    0.136814     0.075175   0.197039              28    A_24
#  2    0.417728     0.356413   0.478075              28    A_24
#  3    0.202357     0.141055   0.262669              28    A_24
#  4    0.625550     0.563923   0.686395              28    A_24
#  ..        ...          ...        ...             ...     ...
#  290  0.164434     0.066834   0.260282              76    A_24
#  291  0.289860     0.192327   0.385969              76    A_24
#  292  0.717522     0.623465   0.801114              76    A_24
#  293  0.480228     0.382724   0.575508              76    A_24
#  294  0.751341     0.657618   0.838541              76    A_24
#
#       temperature_ambient  C/10 discharge capacity  C/5 discharge capacity  \
#  0                   31.0                    64.34                   64.25
#  1                   31.0                    64.34                   64.25
#  2                   31.0                    64.34                   64.25
#  3                   31.0                    64.34                   64.25
#  4                   31.0                    64.34                   64.25
#  ..                   ...                      ...                     ...
#  290                 46.0                    65.05                   64.70
#  291                 46.0                    65.05                   64.70
#  292                 46.0                    65.05                   64.70
#  293                 46.0                    65.05                   64.70
#  294                 46.0                    65.05                   64.70
#
#       C/2 discharge capacity  1C discharge capacity  ...  40  41  42  43  \
#  0                     63.63                  62.78  ... NaN NaN NaN NaN
#  1                     63.63                  62.78  ... NaN NaN NaN NaN
#  2                     63.63                  62.78  ... NaN NaN NaN NaN
#  3                     63.63                  62.78  ... NaN NaN NaN NaN
#  4                     63.63                  62.78  ... NaN NaN NaN NaN
#  ..                      ...                    ...  ...  ..  ..  ..  ..
#  290                   64.51                  64.41  ... NaN NaN NaN NaN
#  291                   64.51                  64.41  ... NaN NaN NaN NaN
#  292                   64.51                  64.41  ... NaN NaN NaN NaN
#  293                   64.51                  64.41  ... NaN NaN NaN NaN
#  294                   64.51                  64.41  ... NaN NaN NaN NaN
#
#              44         45  46  47  48  49
#  0    58.821854        NaN NaN NaN NaN NaN
#  1    56.443111        NaN NaN NaN NaN NaN
#  2    57.301575        NaN NaN NaN NaN NaN
#  3    57.485790        NaN NaN NaN NaN NaN
#  4    56.306587        NaN NaN NaN NaN NaN
#  ..         ...        ...  ..  ..  ..  ..
#  290        NaN  57.034344 NaN NaN NaN NaN
#  291        NaN  58.561646 NaN NaN NaN NaN
#  292        NaN  60.164680 NaN NaN NaN NaN
#  293        NaN  59.076527 NaN NaN NaN NaN
#  294        NaN  58.299973 NaN NaN NaN NaN
#
#  [295 rows x 74 columns],
#  'C/3 discharge capacity, PsRP_2_C/2, features_per_iteration': [],
#  'C/3 discharge capacity, PsRP_2_1C':      soc_mean  soc_initial  soc_final  measurement_id cell_id  \
#  0    0.725459     0.660451   0.790266              28    A_24
#  1    0.386075     0.324512   0.451118              28    A_24
#  2    0.246699     0.181874   0.310837              28    A_24
#  3    0.593506     0.528415   0.658555              28    A_24
#  4    0.345802     0.280807   0.410893              28    A_24
#  ..        ...          ...        ...             ...     ...
#  248  0.153347     0.065525   0.240449              75    A_23
#  249  0.250372     0.145961   0.359066              76    A_24
#  250  0.110772     0.006120   0.209199              76    A_24
#  251  0.262411     0.157679   0.364057              76    A_24
#  252  0.455747     0.352990   0.558582              76    A_24
#
#       temperature_ambient  C/10 discharge capacity  C/5 discharge capacity  \
#  0                   31.0                    64.34                   64.25
#  1                   31.0                    64.34                   64.25
#  2                   31.0                    64.34                   64.25
#  3                   31.0                    64.34                   64.25
#  4                   31.0                    64.34                   64.25
#  ..                   ...                      ...                     ...
#  248                 46.0                    50.85                   50.67
#  249                 46.0                    65.05                   64.70
#  250                 46.0                    65.05                   64.70
#  251                 46.0                    65.05                   64.70
#  252                 46.0                    65.05                   64.70
#
#       C/2 discharge capacity  1C discharge capacity  ...         40         41  \
#  0                     63.63                  62.78  ...        NaN  58.654743
#  1                     63.63                  62.78  ...        NaN  56.145412
#  2                     63.63                  62.78  ...        NaN  57.407944
#  3                     63.63                  62.78  ...        NaN  58.298512
#  4                     63.63                  62.78  ...        NaN  56.919693
#  ..                      ...                    ...  ...        ...        ...
#  248                   50.33                  50.08  ...  61.908562  60.836765
#  249                   64.51                  64.41  ...  58.366642        NaN
#  250                   64.51                  64.41  ...  60.611847        NaN
#  251                   64.51                  64.41  ...  61.290504        NaN
#  252                   64.51                  64.41  ...  57.553913        NaN
#
#              42  43  44         45  46         47         48  49
#  0          NaN NaN NaN        NaN NaN  59.221981        NaN NaN
#  1          NaN NaN NaN        NaN NaN  58.785995        NaN NaN
#  2          NaN NaN NaN        NaN NaN  59.035297        NaN NaN
#  3          NaN NaN NaN        NaN NaN  57.967094        NaN NaN
#  4          NaN NaN NaN        NaN NaN  59.189957        NaN NaN
#  ..         ...  ..  ..        ...  ..        ...        ...  ..
#  248        NaN NaN NaN  61.395229 NaN        NaN        NaN NaN
#  249  59.641998 NaN NaN        NaN NaN        NaN  56.965862 NaN
#  250  56.253201 NaN NaN        NaN NaN        NaN  61.221447 NaN
#  251  53.462826 NaN NaN        NaN NaN        NaN  58.841843 NaN
#  252  58.586285 NaN NaN        NaN NaN        NaN  55.145206 NaN
#
#  [253 rows x 74 columns],
#  'C/3 discharge capacity, PsRP_2_1C, features_per_iteration': []}
